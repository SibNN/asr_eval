# %%
from asr_eval.bench.evaluator2 import Evaluator
# !find ./outputs -name "*.pkl" -type f -delete
evaluator = Evaluator()
evaluator.load_results(max_sample_idx=1, exclude_datasets=['youtube-lectures'])

# %%
print(evaluator.get_multiple_alignments('fleurs')[0].view().render_as_text())

# %%
# %%bash
#
# # DATASETS="-d multivariant-v1-200 common-voice-17.0 fleurs golos-farfield podlodka-full resd speech-massive -m 200"
#
# # tmp/venv_whisper/bin/python -m asr_eval.bench.run -p whisper-large-v3-turbo $DATASETS
# # tmp/venv_whisper/bin/python -m asr_eval.bench.run -p whisper-large-v3 $DATASETS
# # tmp/venv_gigaam/bin/python -m asr_eval.bench.run -p gigaam-ctc $DATASETS
# # tmp/venv_gigaam/bin/python -m asr_eval.bench.run -p gigaam-rnnt-vad $DATASETS
# # tmp/venv_flamingo/bin/python -m asr_eval.bench.run -p flamingo-ru-vad $DATASETS
# # tmp/venv_tone/bin/python -m asr_eval.bench.run -p t-one-vad $DATASETS
# # tmp/venv_vosk/bin/python -m asr_eval.bench.run -p vosk-0.54-vad $DATASETS
# # tmp/venv_yandex_speechkit/bin/python -m asr_eval.bench.run -p yandex-speechkit $DATASETS
# # tmp/venv_pisets/bin/python -m asr_eval.bench.run -p pisets-ru-whisper-large-v3 $DATASETS
# # tmp/venv_voxtral/bin/python -m asr_eval.bench.run -p voxtral-3B $DATASETS
# # tmp/venv_qwen2audio/bin/python -m asr_eval.bench.run -p qwen2-audio-vad $DATASETS
# # tmp/venv_canary/bin/python -m asr_eval.bench.run -p canary-1b-v2 $DATASETS
#
# # tmp/venv_whisper/bin/python -m asr_eval.bench.run -p whisper-large-v3 -d youtube-lectures
# # tmp/venv_pisets/bin/python -m asr_eval.bench.run -p pisets-ru-whisper-large-v3 -d youtube-lectures
# # tmp/venv_gigaam/bin/python -m asr_eval.bench.run -p gigaam-ctc -d youtube-lectures
# # tmp/venv_gigaam/bin/python -m asr_eval.bench.run -p gigaam-rnnt-vad -d youtube-lectures
# # tmp/venv_voxtral/bin/python -m asr_eval.bench.run -p voxtral-3B-mp3 -d youtube-lectures

# %%
labels = ['a', 'b', 'c']
vals1 = [10, 4, 6]
vals2 = [11, 0, 2]

# %%
import pandas as pd

pd.DataFrame({'pipeline': 'pipeline 1', 'type': labels, 'val': vals1})
# Out:
#      pipeline type  val
# 0  pipeline 1    a   10
# 1  pipeline 1    b    4
# 2  pipeline 1    c    6

# %%
import plotly.express as px
long_df = px.data.medals_long()

fig = px.bar(long_df, x = "nation", y = "count",
             color = "medal", title = "Long-Form Input")
fig.show()
